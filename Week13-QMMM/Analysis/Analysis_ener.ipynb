# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
npt_data = np.loadtxt("../Outputs/NPT-1.ener")
nvt_data = np.loadtxt("../Outputs/NVT-1.ener")

# %%
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.plot(npt_data[:, 1], npt_data[:, 4])
plt.title("Potential Energy against Time for NPT")
plt.savefig("../Figures/npt_pot_ener_time.png")
plt.show()

# %%
plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.plot(nvt_data[:, 1], nvt_data[:, 4])
plt.title("Potential Energy against Time for NVT")
plt.savefig("../Figures/nvt_pot_ener_time.png")

# %%
monitor_data = np.loadtxt("../Outputs/monitor/MONITOR-1.ener")

plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.plot(monitor_data[:, 1], monitor_data[:, 4])
plt.title("Potential Energy against Time for QM/MM")
plt.savefig("../Figures/monitor_pot_ener_time.png")

# %%
metad1_data = np.loadtxt("../Outputs/metad1_initmonitor/METADYN-1.ener")

plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.plot(metad1_data[:, 1], metad1_data[:, 4])
plt.title("Potential Energy against Time for Metadynamics QM/MM")
plt.savefig("../Figures/metad1_pot_ener_time.png")

# %%
metad1_hills_data = np.loadtxt("../Outputs/metad1_initmonitor_freqhills/METADYN-1.ener")

plt.xlabel("Time (fs)")
plt.ylabel("Potential Energy (a.u.)")
plt.plot(metad1_hills_data[:, 1], metad1_hills_data[:, 4])
plt.title("Potential Energy against Time for Frequent Metadynamics QM/MM")
plt.savefig("../Figures/metad1_freq_pot_ener_time.png")
