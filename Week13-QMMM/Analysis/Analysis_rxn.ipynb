# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt

# %%
rxn_data = np.loadtxt("../Outputs/monitor/MONITOR-COLVAR.metadynLog")
plt.plot(rxn_data[:,0], rxn_data[:,1], label = "Standard QM/MM")

rxn_data = np.loadtxt("../Outputs/metad1_initmonitor/METADYN-COLVAR.metadynLog")
plt.plot(rxn_data[:,0], rxn_data[:,1], label = "Metadynamics QM/MM")

rxn_data = np.loadtxt("../Outputs/metad1_initmonitor_freqhills/METADYN-COLVAR.metadynLog")
plt.plot(rxn_data[:,0], rxn_data[:,1], label = "Freq Metadynamics QM/MM")

info = "Metadynamics info: hill height = 1.5, hill width = 0.5, hill min freq = 100 steps"
x = -4000
y = -27.5
plt.text(x, y, info)

info = "Freq Metadynamics info: hill height = 1.5, hill width = 0.5, hill min freq = 20 steps"
x = -4000
y = -30.5
plt.text(x, y, info)

plt.xlabel("Time (fs)")
plt.ylabel("d(5663-5675) - d(5670 - 5671) (A)")
plt.title("Reaction Coord. against Time")
plt.legend()
plt.savefig("../Figures/rxn_time.png")
plt.show()
